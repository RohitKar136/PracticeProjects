# %%
x=10
print(x)
# Out:
# 10

# %%
import pandas as PD

# %%
Dat1=PD.read_excel(r'C:\Users\User\Desktop\DAT1.xlsx')

# %%
Dat1
# Out:
#     Name  Age  Salary
# 0   Upma   23   10000
# 1  Delta   23   10000
# 2   Dany   21   10000

# %%
Dat2 = PD.read_csv(r'C:\Users\User\Desktop\DAT2.csv')

# %%
Dat2
# Out:
#     Name  Age  Salary
# 0   Upma   23   10000
# 1  Delta   23   10000
# 2   Dany   21   10000

# %%
import os

# %%
import pandas as PD

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User'

# %%
Dat3 = PD.read_csv('Dat3.tsv', sep ='\t')

# %%
Dat3
# Out:
#    rollno   name  batch
# 0      21  Rohit   1840
# 1      25  Bibek   1456
# 2      28  Rajiv   1544
# 3      30  Abhik   4151
